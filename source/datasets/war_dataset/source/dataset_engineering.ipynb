# %%
import pandas as pd
from pandas import DataFrame, Series

# %%
df = pd.read_csv('inter_war_data.csv')

# %%
cols = df.columns.tolist()

# %%
cols = ['WarNum',
 'WarName',
 'WarType',
 'TransFrom',
 'TransTo',
 'WhereFought',
 'Initiator',
 'Outcome',
 'ccode',
 'StateName',
 'Side',
 'BatDeath',
 'StartDay1',
 'StartMonth1',
 'StartYear1',
 'EndDay1',
 'EndMonth1',
 'EndYear1',
 'StartDay2',
 'StartMonth2',
 'StartYear2',
 'EndDay2',
 'EndMonth2',
 'EndYear2',
 'Version']
df = df[cols]

# %%
df.to_csv('inter_war_data_modified.csv', index=False)

# %%
df
# Out:
#      WarNum                   WarName  WarType TransFrom  TransTo  \
# 0         1        Franco-Spanish War        1       503       -8
# 1         1        Franco-Spanish War        1       503       -8
# 2         4       First Russo-Turkish        1       506       -8
# 3         4       First Russo-Turkish        1       506       -8
# 4         7          Mexican-American        1        -8       -8
# 5         7          Mexican-American        1        -8       -8
# 6        10          Austro-Sardinian        1        -8       -8
# 7        10          Austro-Sardinian        1       551       -8
# 8        10          Austro-Sardinian        1       551       -8
# 9        10          Austro-Sardinian        1        -8       -8
# 10       13  First Schleswig-Holstein        1        -8       -8
# 11       13  First Schleswig-Holstein        1        -8       -8
# 12       16            Roman Republic        1        -8       -8
# ...
