# %%
import json
import nltk
from nltk import FreqDist
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from operator import itemgetter

# %%
with open('war_texts_raw.json') as data_file:    
    data = json.load(data_file)

# %%
def preprocess(sentence):
    
    sentence = sentence.lower()
    tokenizer = RegexpTokenizer(r'([0-9]+([,.][0-9]{1,3})+)|((?<!\[)\b\d+\b(?!\]))|(\b([A-Z]\.)+)|(\w+)')
    tokens = [a or b or c or d or e or f for a,b,c,d,e,f in tokenizer.tokenize(sentence)]
    filtered_words = [w for w in tokens if not w in stopwords.words('english')]
    
    return filtered_words

# %%
war_texts_list = []
for war in data['texts']:
    war_id = war['war_id']
    war_relevant_words_dict = {u'war_id': war_id, u'words': []}
    
    text = war['text']
    if text:
        preprocessed_text = preprocess(text)
        fdist = FreqDist(preprocessed_text)
        relevant_words_tup = sorted(fdist.iteritems(), key=itemgetter(1), reverse=True)[:30]
        for tup in relevant_words_tup:
            d = {u'text': tup[0], u'size': tup[1]}
            war_relevant_words_dict[u'words'].append(d)
            
    war_texts_list.append(war_relevant_words_dict)
# Out:
# [u'there', u'were', u'multiple', u'reasons', u'for', u'the', u'mexican', u'war', u'one', u'immediate', u'cause', u'was', u'the', u'american', u'annexation', u'of', u'texas', u'the', u'mexican', u'government', u'regarded', u'this', u'a', u'declaration', u'of', u'war', u'and', u'removed', u'the', u'mexican', u'minister', u'from', u'washington', u'another', u'cause', u'was', u'american', u'claims', u'against', u'mexico', u'arising', u'from', u'the', u'mexican', u'revolutions', u'following', u'mexico', u's', u'independence', u'from', u'spain', u'american', u'and', u'european', u'cartographers', u'fixed', u'the', u'texas', u'border', u'at', u'the', u'neuces', u'river', u'prior', u'to', u'texas', u's', u'independence', u'the', u'neuces', u'river', u'was', u'recognized', u'as', u'the', u'northern', u'boundary', u'of', u'mexico', u'spain', u'had', u'fixed', u'the', u'neuces', u'as', u'a', u'border', u'in', u'1816', u'and', u'the', u'united', u'states', u'ratified', u'it', u'in', u'the', u'1819', u'treaty', u'by', u'which', u'the', u'united', u'states', u'had', u'purchased', u'florida', u'and', u'renounced', u'claims', u'to', u'texas', u'throughout', u'the', u'1820s', u'americans', u'settled', u'in', u'the', u'vast', u'territory', u'of', u'texas', u'often', u'with', u'land', u'grants', u'from', u'the', u'mexican', u'government', u'their', u'numbers', u'soon', u'alarmed', u'the', u'authorities', u'however', u'who', u'prohibited', u'further', u'immigration', u'in', u'1830', u'in', u'1834',